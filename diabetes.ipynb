# %% [markdown]
# ## MD MEHER HASSAN CHOWDHIRY
# ## 1155645
# ## The Entire Code solely done by me

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('darkgrid')
# %matplotlib inline

# %%
## Reading Dataset
df=pd.read_csv("diabetes.csv")

# %% [markdown]
# ## EDA

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
print('Nan values in the dataset : ',df.isna().sum().sum())
print('Duplicate values in the dataset : ',df.duplicated().sum())
# Out:
# Nan values in the dataset :  0
# Duplicate values in the dataset :  0

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
sns.pairplot(df,hue='Outcome')

# %%
## Finding correlation between features
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_8095e_row0_col0,#T_8095e_row1_col1,#T_8095e_row2_col2,#T_8095e_row3_col3,#T_8095e_row4_col4,#T_8095e_row5_col5,#T_8095e_row6_col6,#T_8095e_row7_col7,#T_8095e_row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_8095e_row0_col1{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_8095e_row0_col2{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_8095e_row0_col3,#T_8095e_row7_col4{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_8095e_row0_col4,#T_8095e_row0_col5,#T_8095e_row0_col6,#T_8095e_row2_col8,#T_8095e_row3_col0,#T_8095e_row3_col1,#T_8095e_row3_col7,#T_8095e_row6_col2,#T_8095e_row7_col3{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_8095e_row0_col7{
#             background-color:  #f1cdba;
#             color:  #000000;
#         }#T_8095e_row0_col8,#T_8095e_row1_col6{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_8095e_row1_col0{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_8095e_row1_col2,#T_8095e_row6_col8{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_8095e_row1_col3{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_8095e_row1_col4{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_8095e_row1_col5,#T_8095e_row3_col6{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_8095e_row1_col7{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_8095e_row1_col8{
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }#T_8095e_row2_col0,#T_8095e_row7_col2{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_8095e_row2_col1{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_8095e_row2_col3{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_8095e_row2_col4{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_8095e_row2_col5,#T_8095e_row6_col3{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_8095e_row2_col6{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_8095e_row2_col7{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_8095e_row3_col2,#T_8095e_row5_col1{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_8095e_row3_col4{
#             background-color:  #d6dce4;
#             color:  #000000;
#         }#T_8095e_row3_col5{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_8095e_row3_col8{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_8095e_row4_col0{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_8095e_row4_col1{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_8095e_row4_col2{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_8095e_row4_col3{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_8095e_row4_col5{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_8095e_row4_col6{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_8095e_row4_col7,#T_8095e_row7_col6{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_8095e_row4_col8{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_8095e_row5_col0{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_8095e_row5_col2,#T_8095e_row5_col4{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_8095e_row5_col3{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_8095e_row5_col6,#T_8095e_row8_col3{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_8095e_row5_col7{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_8095e_row5_col8{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_8095e_row6_col0{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_8095e_row6_col1{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_8095e_row6_col4{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_8095e_row6_col5{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_8095e_row6_col7{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_8095e_row7_col0{
#             background-color:  #efcfbf;
#             color:  #000000;
#         }#T_8095e_row7_col1{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_8095e_row7_col5{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_8095e_row7_col8{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_8095e_row8_col0,#T_8095e_row8_col5{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_8095e_row8_col1{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_8095e_row8_col2{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_8095e_row8_col4{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_8095e_row8_col6{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_8095e_row8_col7{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }</style><table id="T_8095e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pregnancies</th>        <th class="col_heading level0 col1" >Glucose</th>        <th class="col_heading level0 col2" >BloodPressure</th>        <th class="col_heading level0 col3" >SkinThickness</th>        <th class="col_heading level0 col4" >Insulin</th>        <th class="col_heading level0 col5" >BMI</th>        <th class="col_heading level0 col6" >DiabetesPedigreeFunction</th>        <th class="col_heading level0 col7" >Age</th>        <th class="col_heading level0 col8" >Outcome</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8095e_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#                         <td id="T_8095e_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_8095e_row0_col1" class="data row0 col1" >0.129459</td>
#                         <td id="T_8095e_row0_col2" class="data row0 col2" >0.141282</td>
#                         <td id="T_8095e_row0_col3" class="data row0 col3" >-0.081672</td>
#                         <td id="T_8095e_row0_col4" class="data row0 col4" >-0.073535</td>
#                         <td id="T_8095e_row0_col5" class="data row0 col5" >0.017683</td>
#                         <td id="T_8095e_row0_col6" class="data row0 col6" >-0.033523</td>
#                         <td id="T_8095e_row0_col7" class="data row0 col7" >0.544341</td>
#                         <td id="T_8095e_row0_col8" class="data row0 col8" >0.221898</td>
#             </tr>
#             <tr>
#                         <th id="T_8095e_level0_row1" class="row_heading level0 row1" >Glucose</th>
#                         <td id="T_8095e_row1_col0" class="data row1 col0" >0.129459</td>
#                         <td id="T_8095e_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_8095e_row1_col2" class="data row1 col2" >0.152590</td>
#                         <td id="T_8095e_row1_col3" class="data row1 col3" >0.057328</td>
#                         <td id="T_8095e_row1_col4" class="data row1 col4" >0.331357</td>

# %%
cmap = sns.diverging_palette(70,20,s=50, l=40, n=6, as_cmap=True)
matrix_cor_ucun = df.corr()
f, ax = plt.subplots(figsize=(12,12))
sns.heatmap(matrix_cor_ucun,cmap=cmap,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.set_theme(style="whitegrid")
sns.boxplot(x="Age", data=df, palette="Set3")
plt.title("Age Distribution")
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
sns.boxplot(df['Glucose'])
# Out:
# C:\Users\RAMBO\anaconda3\envs\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Glucose'>

# %%
sns.set_theme(style="whitegrid")
sns.boxplot(x="Age", data=df, palette="Set3")
plt.title("Age Distribution")
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
## Visualisation of every feature.
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
df.hist(ax = ax)
# Out:
# C:\Users\RAMBO\anaconda3\envs\python37\lib\site-packages\ipykernel_launcher.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   after removing the cwd from sys.path.
# array([[<AxesSubplot:title={'center':'Pregnancies'}>,
#         <AxesSubplot:title={'center':'Glucose'}>,
#         <AxesSubplot:title={'center':'BloodPressure'}>],
#        [<AxesSubplot:title={'center':'SkinThickness'}>,
#         <AxesSubplot:title={'center':'Insulin'}>,
#         <AxesSubplot:title={'center':'BMI'}>],
#        [<AxesSubplot:title={'center':'DiabetesPedigreeFunction'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Outcome'}>]], dtype=object)

# %%
## checking data imbalance
df.Outcome.value_counts().plot(kind='bar')
plt.xlabel("Categories ( Yes No)")
plt.ylabel("Count")
plt.title("Outcome ")
# Out:
# Text(0.5, 1.0, 'Outcome ')

# %%
X=df.drop('Outcome',axis=1)
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y=df['Outcome']
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
## Removing Data Imbalance
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=1000, n_features=2, n_informative=2,
                           n_redundant=0, n_repeated=0, n_classes=2,
                           n_clusters_per_class=1,
                           weights=[0.01, 0.05],
                           class_sep=0.8, random_state=0)
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=0)
X_resampled, y_resampled = ros.fit_resample(X, y)
from collections import Counter
print(sorted(Counter(y_resampled).items()))
# Out:
# [(0, 519), (1, 519)]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled,test_size=0.2,random_state=0)

# %%
X_train.shape
# Out:
# (830, 2)

# %%
y_train.shape
# Out:
# (830,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
##scaling
sc_x=StandardScaler()
X_train=sc_x.fit_transform(X_train)
X_test=sc_x.transform(X_test)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Flatten, Dense, Softmax, Conv2D, MaxPooling2D

# %%
##adding layers for binary classification
model = Sequential(name="BinaryClassification")
#Input Layer                 
model.add(Dense(4, activation='relu', input_shape=[2], name="Input"))

#Hidden Layer 
model.add(Dense(4, activation='relu', name="Dense"))

#Output Layer
model.add(Dense(1, activation='sigmoid', name="Output"))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['binary_accuracy'])
model.summary()
# Out:
# Model: "BinaryClassification"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (Dense)                (None, 4)                 12
# _________________________________________________________________
# Dense (Dense)                (None, 4)                 20
# _________________________________________________________________
# Output (Dense)               (None, 1)                 5
# =================================================================
# Total params: 37
# Trainable params: 37
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, validation_split=0.15, batch_size=32, epochs=50, verbose= 1)
# Out:
# Train on 705 samples, validate on 125 samples
# Epoch 1/50
# 705/705 [==============================] - 2s 2ms/sample - loss: 0.6686 - binary_accuracy: 0.7603 - val_loss: 0.6384 - val_binary_accuracy: 0.7760
# Epoch 2/50
# 705/705 [==============================] - 0s 272us/sample - loss: 0.6633 - binary_accuracy: 0.7716 - val_loss: 0.6329 - val_binary_accuracy: 0.7840
# Epoch 3/50
# 705/705 [==============================] - 0s 273us/sample - loss: 0.6579 - binary_accuracy: 0.7716 - val_loss: 0.6268 - val_binary_accuracy: 0.7840
# Epoch 4/50
# 705/705 [==============================] - 0s 250us/sample - loss: 0.6521 - binary_accuracy: 0.7730 - val_loss: 0.6206 - val_binary_accuracy: 0.7920
# Epoch 5/50
# 705/705 [==============================] - 0s 251us/sample - loss: 0.6458 - binary_accuracy: 0.7830 - val_loss: 0.6131 - val_binary_accuracy: 0.8080
# Epoch 6/50
# 705/705 [==============================] - 0s 261us/sample - loss: 0.6387 - binary_accuracy: 0.7943 - val_loss: 0.6046 - val_binary_accuracy: 0.8160
# Epoch 7/50
# 705/705 [==============================] - 0s 204us/sample - loss: 0.6308 - binary_accuracy: 0.8057 - val_loss: 0.5957 - val_binary_accuracy: 0.8240
# Epoch 8/50
# 705/705 [==============================] - 0s 239us/sample - loss: 0.6216 - binary_accuracy: 0.8142 - val_loss: 0.5851 - val_binary_accuracy: 0.8400
# Epoch 9/50
# 705/705 [==============================] - 0s 261us/sample - loss: 0.6111 - binary_accuracy: 0.8199 - val_loss: 0.5726 - val_binary_accuracy: 0.8480
# Epoch 10/50
# 705/705 [==============================] - 0s 295us/sample - loss: 0.5990 - binary_accuracy: 0.8284 - val_loss: 0.5586 - val_binary_accuracy: 0.8720
# Epoch 11/50
# 705/705 [==============================] - 0s 261us/sample - loss: 0.5864 - binary_accuracy: 0.8255 - val_loss: 0.5454 - val_binary_accuracy: 0.8720
# Epoch 12/50
# 705/705 [==============================] - 0s 261us/sample - loss: 0.5737 - binary_accuracy: 0.8241 - val_loss: 0.5317 - val_binary_accuracy: 0.8640
# Epoch 13/50
# 705/705 [==============================] - 0s 193us/sample - loss: 0.5606 - binary_accuracy: 0.8213 - val_loss: 0.5190 - val_binary_accuracy: 0.8880
# Epoch 14/50
# 705/705 [==============================] - 0s 193us/sample - loss: 0.5477 - binary_accuracy: 0.8255 - val_loss: 0.5049 - val_binary_accuracy: 0.8960
# Epoch 15/50
# 705/705 [==============================] - 0s 273us/sample - loss: 0.5353 - binary_accuracy: 0.8255 - val_loss: 0.4925 - val_binary_accuracy: 0.8960
# Epoch 16/50
# 705/705 [==============================] - 0s 170us/sample - loss: 0.5239 - binary_accuracy: 0.8241 - val_loss: 0.4812 - val_binary_accuracy: 0.8960
# Epoch 17/50
# 705/705 [==============================] - 0s 159us/sample - loss: 0.5123 - binary_accuracy: 0.8284 - val_loss: 0.4703 - val_binary_accuracy: 0.8960
# Epoch 18/50
# 705/705 [==============================] - 0s 148us/sample - loss: 0.5019 - binary_accuracy: 0.8270 - val_loss: 0.4607 - val_binary_accuracy: 0.9040
# Epoch 19/50
# 705/705 [==============================] - 0s 147us/sample - loss: 0.4922 - binary_accuracy: 0.8284 - val_loss: 0.4519 - val_binary_accuracy: 0.9120
# Epoch 20/50
# 705/705 [==============================] - 0s 137us/sample - loss: 0.4836 - binary_accuracy: 0.8270 - val_loss: 0.4423 - val_binary_accuracy: 0.9120
# Epoch 21/50
# 705/705 [==============================] - 0s 147us/sample - loss: 0.4754 - binary_accuracy: 0.8312 - val_loss: 0.4348 - val_binary_accuracy: 0.9120
# Epoch 22/50
# 705/705 [==============================] - 0s 137us/sample - loss: 0.4679 - binary_accuracy: 0.8312 - val_loss: 0.4282 - val_binary_accuracy: 0.9200
# Epoch 23/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.4613 - binary_accuracy: 0.8369 - val_loss: 0.4239 - val_binary_accuracy: 0.9360
# Epoch 24/50
# 705/705 [==============================] - 0s 148us/sample - loss: 0.4545 - binary_accuracy: 0.8426 - val_loss: 0.4177 - val_binary_accuracy: 0.9360
# Epoch 25/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.4486 - binary_accuracy: 0.8454 - val_loss: 0.4123 - val_binary_accuracy: 0.9280
# Epoch 26/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.4433 - binary_accuracy: 0.8553 - val_loss: 0.4078 - val_binary_accuracy: 0.9200
# Epoch 27/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.4376 - binary_accuracy: 0.8539 - val_loss: 0.4033 - val_binary_accuracy: 0.9120
# Epoch 28/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.4326 - binary_accuracy: 0.8553 - val_loss: 0.3980 - val_binary_accuracy: 0.9200
# Epoch 29/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.4285 - binary_accuracy: 0.8567 - val_loss: 0.3938 - val_binary_accuracy: 0.9200
# Epoch 30/50
# 705/705 [==============================] - 0s 148us/sample - loss: 0.4248 - binary_accuracy: 0.8610 - val_loss: 0.3909 - val_binary_accuracy: 0.9280
# Epoch 31/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.4215 - binary_accuracy: 0.8652 - val_loss: 0.3874 - val_binary_accuracy: 0.9280
# Epoch 32/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.4177 - binary_accuracy: 0.8638 - val_loss: 0.3832 - val_binary_accuracy: 0.9280
# Epoch 33/50
# 705/705 [==============================] - 0s 148us/sample - loss: 0.4146 - binary_accuracy: 0.8667 - val_loss: 0.3799 - val_binary_accuracy: 0.9200
# Epoch 34/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.4121 - binary_accuracy: 0.8638 - val_loss: 0.3833 - val_binary_accuracy: 0.9040
# Epoch 35/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.4094 - binary_accuracy: 0.8624 - val_loss: 0.3788 - val_binary_accuracy: 0.9040
# Epoch 36/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.4067 - binary_accuracy: 0.8624 - val_loss: 0.3747 - val_binary_accuracy: 0.9040
# Epoch 37/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.4046 - binary_accuracy: 0.8610 - val_loss: 0.3722 - val_binary_accuracy: 0.9040
# Epoch 38/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.4019 - binary_accuracy: 0.8652 - val_loss: 0.3670 - val_binary_accuracy: 0.9040
# Epoch 39/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.3997 - binary_accuracy: 0.8638 - val_loss: 0.3648 - val_binary_accuracy: 0.9040
# Epoch 40/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.3976 - binary_accuracy: 0.8638 - val_loss: 0.3627 - val_binary_accuracy: 0.9040
# Epoch 41/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.3956 - binary_accuracy: 0.8624 - val_loss: 0.3626 - val_binary_accuracy: 0.9040
# Epoch 42/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.3939 - binary_accuracy: 0.8582 - val_loss: 0.3596 - val_binary_accuracy: 0.9040
# Epoch 43/50
# 705/705 [==============================] - 0s 159us/sample - loss: 0.3922 - binary_accuracy: 0.8582 - val_loss: 0.3573 - val_binary_accuracy: 0.8960
# Epoch 44/50
# 705/705 [==============================] - 0s 125us/sample - loss: 0.3905 - binary_accuracy: 0.8582 - val_loss: 0.3546 - val_binary_accuracy: 0.9040
# Epoch 45/50
# 705/705 [==============================] - 0s 113us/sample - loss: 0.3891 - binary_accuracy: 0.8596 - val_loss: 0.3527 - val_binary_accuracy: 0.9040
# Epoch 46/50
# 705/705 [==============================] - 0s 126us/sample - loss: 0.3875 - binary_accuracy: 0.8567 - val_loss: 0.3503 - val_binary_accuracy: 0.8960
# Epoch 47/50
# 705/705 [==============================] - 0s 125us/sample - loss: 0.3860 - binary_accuracy: 0.8582 - val_loss: 0.3474 - val_binary_accuracy: 0.8960
# Epoch 48/50
# 705/705 [==============================] - 0s 125us/sample - loss: 0.3845 - binary_accuracy: 0.8596 - val_loss: 0.3459 - val_binary_accuracy: 0.8960
# Epoch 49/50
# 705/705 [==============================] - 0s 136us/sample - loss: 0.3830 - binary_accuracy: 0.8596 - val_loss: 0.3437 - val_binary_accuracy: 0.8960
# Epoch 50/50
# 705/705 [==============================] - 0s 125us/sample - loss: 0.3816 - binary_accuracy: 0.8610 - val_loss: 0.3426 - val_binary_accuracy: 0.8960

# %%
model.evaluate(X_test, y_test)
# Out:
# 208/208 [==============================] - 0s 115us/sample - loss: 0.3979 - binary_accuracy: 0.8510
# [0.3979162344565758, 0.85096157]

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
## model accuracy for training and validation
plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['val_binary_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
